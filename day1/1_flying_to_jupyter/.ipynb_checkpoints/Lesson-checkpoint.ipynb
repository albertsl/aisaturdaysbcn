# %%
print("This is how you run code")
# Out:
# This is how you run code

# %%
print("You can run code by pressing Ctrl+Enter")
# Out:
# You can run code by pressing Ctrl+Enter

# %%
print("You can run the code and go to the next cell by pressing Shift+Enter")
# Out:
# You can run the code and go to the next cell by pressing Shift+Enter

# %%
print("The number on the left determines the order of execution")
# Out:
# The number on the left determines the order of execution

# %%
name = "Albert"

# %%
print(name)
# Out:
# Albert

# %%
name = "Miguel"

# %% [markdown]
# # Markdown!
# We can change the cell type to Markdown to write formatted code, think of it as a simplified version of Word.
#
# ![fireworks](https://media.giphy.com/media/nbJUuYFI6s0w0/giphy.gif)
#
# ## Let's keep going
#
# We can execute bash commands from Jupyter Notebook by typing a ! before the command. As always it is easier to learn with an example so there we go
#
# ![Stupid dance](https://media.giphy.com/media/IhGsY7dhRPiCI/giphy.gif)

# %%
# !ls
# Out:
# Lesson.ipynb

# %%
believe_me_this_is_going_to_be_crazy = 0
while True:
    believe_me_this_is_going_to_be_crazy += 1
    print("Isn't it crazy", believe_me_this_is_going_to_be_crazy)
    
print("Wasn't it crazy?")
# Out:
# Isn't it crazy 1
# Isn't it crazy 2
# Isn't it crazy 3
# Isn't it crazy 4
# Isn't it crazy 5
# Isn't it crazy 6
# Isn't it crazy 7
# Isn't it crazy 8
# Isn't it crazy 9
# Isn't it crazy 10
# Isn't it crazy 11
# Isn't it crazy 12
# Isn't it crazy 13
# Isn't it crazy 14
# Isn't it crazy 15
# Isn't it crazy 16
# Isn't it crazy 17
# Isn't it crazy 18
# Isn't it crazy 19
# Isn't it crazy 20
# Isn't it crazy 21
# Isn't it crazy 22
# Isn't it crazy 23
# Isn't it crazy 24
# Isn't it crazy 25
# Isn't it crazy 26
# Isn't it crazy 27
# Isn't it crazy 28
# Isn't it crazy 29
# Isn't it crazy 30
# Isn't it crazy 31
# Isn't it crazy 32
# Isn't it crazy 33
# Isn't it crazy 34
# Isn't it crazy 35
# Isn't it crazy 36
# Isn't it crazy 37
# Isn't it crazy 38
# Isn't it crazy 39
# Isn't it crazy 40
# Isn't it crazy 41
# Isn't it crazy 42
# Isn't it crazy 43
# Isn't it crazy 44
# Isn't it crazy 45
# Isn't it crazy 46
# Isn't it crazy 47
# Isn't it crazy 48
# Isn't it crazy 49
# Isn't it crazy 50
# ...

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py in <module>()
#    1447         try:
# -> 1448             fontManager = json_load(_fmcache)
#    1449             if (not hasattr(fontManager, '_version') or
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py in json_load(filename)
#     976
# --> 977     with open(filename, 'r') as fh:
#     978         return json.load(fh, object_hook=_json_decode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/albert/.cache/matplotlib/fontList.json'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-64b6e804fec3> in <module>()
# ----> 1 import matplotlib.pyplot as plt
#       2 plt.plot([1,2,3,4])
# ...

# %%
# %matplotlib inline

# %% [markdown]
# If this is your first time running anaconda this command may take some time so let's dance a little bit more.
#
# ![stupid dance 2](https://media.giphy.com/media/4vlZXHoRxvzTG/giphy.gif)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()
